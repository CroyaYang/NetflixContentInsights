# %% [markdown]
# Text Classification Using FastText

# %% [markdown]
# We have a dataset of netflix title. total 4 categories
# 1. teens
# 2. adults
# 3. older kids
# 4. kids
#
# The task is to classify a product into one of the above 4 categories based on the title and description

# %%
import numpy as np
import pandas as pd
df = pd.read_csv(r'netflix_titles.csv',header=0)
print(df.shape)
df.head(3)
# Out:
# (8807, 12)
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
# 2      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
# ...

# %%
df.dropna(inplace=True)
df.shape
# Out:
# (5332, 12)

# %%
df.title.unique()
# Out:
# array(['Sankofa', 'The Great British Baking Show', 'The Starling', ...,
#        'Zombieland', 'Zoom', 'Zubaan'], dtype=object)

# %%
df['title'] = '__label__' + df['title'].astype(str)
df.head(5)
# Out:
#    show_id     type                                   title  \
# 7       s8    Movie                        __label__Sankofa
# 8       s9  TV Show  __label__The Great British Baking Show
# 9      s10    Movie                   __label__The Starling
# 12     s13    Movie                   __label__Je Suis Karl
# 24     s25    Movie                          __label__Jeans
#
#                director                                               cast  \
# 7          Haile Gerima  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8       Andy Devonshire  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9        Theodore Melfi  Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12  Christian Schwochow  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 24           S. Shankar  Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
#
#                                               country          date_added  \
# 7   United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# ...

# %%
df['title_description'] = df['title'] + ' ' + df['description']
df.head(3)
# Out:
#   show_id     type                                   title         director  \
# 7      s8    Movie                        __label__Sankofa     Haile Gerima
# 8      s9  TV Show  __label__The Great British Baking Show  Andy Devonshire
# 9     s10    Movie                   __label__The Starling   Theodore Melfi
#
#                                                 cast  \
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9  Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
#
#                                              country          date_added  \
# 7  United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 8                                     United Kingdom  September 24, 2021
# 9                                      United States  September 24, 2021
#
#    release_year rating   duration  \
# 7          1993  TV-MA    125 min
# 8          2021  TV-14  9 Seasons
# 9          2021  PG-13    104 min
#
# ...

# %%
import re

text = "  VIKI's | Bookcase/Bookshelf (3-Shelf/Shelve, White) | ? . hi"
text = re.sub(r'[^\w\s\']',' ', text)
text = re.sub(' +', ' ', text)
text.strip().lower()
# Out:
# "viki's bookcase bookshelf 3 shelf shelve white hi"

# %%
def preprocess(text):
    text = re.sub(r'[^\w\s\']',' ', text)
    text = re.sub(' +', ' ', text)
    return text.strip().lower()

# %%
df['title_description'] = df['title_description'].map(preprocess)
df.head()
# Out:
#    show_id     type                                   title  \
# 7       s8    Movie                        __label__Sankofa
# 8       s9  TV Show  __label__The Great British Baking Show
# 9      s10    Movie                   __label__The Starling
# 12     s13    Movie                   __label__Je Suis Karl
# 24     s25    Movie                          __label__Jeans
#
#                director                                               cast  \
# 7          Haile Gerima  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8       Andy Devonshire  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9        Theodore Melfi  Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12  Christian Schwochow  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 24           S. Shankar  Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
#
#                                               country          date_added  \
# 7   United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# ...

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(df, test_size=0.2)

# %%
train.shape, test.shape
# Out:
# ((4265, 13), (1067, 13))

# %%
train.to_csv("netflix.train", columns=["title_description"], index=False, header=False)
test.to_csv("netflix.test", columns=["title_description"], index=False, header=False)

# %%
import fasttext

model = fasttext.train_supervised(input="netflix.train")
model.test("netflix.test")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 import fasttext
#       3 model = fasttext.train_supervised(input="netflix.train")
#       4 model.test("netflix.test")
#
# ModuleNotFoundError: No module named 'fasttext'
