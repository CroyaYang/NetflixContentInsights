# %%
import pandas as pd
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report, accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns

# 1. 加载数据集
data_path = "../dataset/preprocessed/netflix_targeted_ages.csv"
df = pd.read_csv(data_path)

# 2. 特征工程
X = df['title'] + ' ' + df['description']
y = df['target_ages']

# 3. 划分数据集和目标变量
skf = StratifiedKFold(n_splits=2, shuffle=True, random_state=42)
for train_index, test_index in skf.split(X, y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # 4. 文本向量化
    vectorizer = TfidfVectorizer()
    X_train_vectorized = vectorizer.fit_transform(X_train)
    X_test_vectorized = vectorizer.transform(X_test)

    # 5. 训练模型
    model = MultinomialNB()
    model.fit(X_train_vectorized, y_train)

    # 6. 预测和评估
    y_pred = model.predict(X_test_vectorized)
    accuracy = accuracy_score(y_test, y_pred)

    print(f'Accuracy: {accuracy}')
    print(classification_report(y_test, y_pred))

# 7. 可视化结果
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap='Blues', xticklabels=model.classes_, yticklabels=model.classes_)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# Accuracy: 0.49772727272727274
#               precision    recall  f1-score   support
#
#       Adults       0.49      0.99      0.65       204
#         Kids       0.00      0.00      0.00        28
#   Older Kids       0.70      0.09      0.16        75
#        Teens       0.65      0.08      0.15       133
#
#     accuracy                           0.50       440
#    macro avg       0.46      0.29      0.24       440
# weighted avg       0.54      0.50      0.37       440
#
# Accuracy: 0.5136363636363637
#               precision    recall  f1-score   support
#
#       Adults       0.51      0.99      0.67       204
#         Kids       1.00      0.07      0.13        28
#   Older Kids       0.62      0.11      0.18        75
#        Teens       0.52      0.11      0.19       133
#
#     accuracy                           0.51       440
#    macro avg       0.66      0.32      0.29       440
# weighted avg       0.56      0.51      0.41       440
# d:\python\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\python\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\python\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 0.47045454545454546
#               precision    recall  f1-score   support
#
#       Adults       0.47      0.97      0.64       204
#         Kids       1.00      0.04      0.07        28
#   Older Kids       0.75      0.04      0.08        75
#        Teens       0.30      0.05      0.08       133
#
#     accuracy                           0.47       440
#    macro avg       0.63      0.27      0.21       440
# weighted avg       0.50      0.47      0.34       440
#
# Accuracy: 0.4863636363636364
# d:\python\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\python\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\python\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\python\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\python\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\python\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#       Adults       0.48      0.98      0.64       204
#         Kids       0.00      0.00      0.00        28
#   Older Kids       0.92      0.16      0.27        75
#        Teens       0.30      0.02      0.04       133
#
#     accuracy                           0.49       440
#    macro avg       0.43      0.29      0.24       440
# weighted avg       0.47      0.49      0.36       440
#
# Accuracy: 0.4818181818181818
#               precision    recall  f1-score   support
#
#       Adults       0.48      1.00      0.65       204
#         Kids       0.00      0.00      0.00        28
#   Older Kids       0.50      0.05      0.10        75
#        Teens       0.50      0.04      0.07       133
#
#     accuracy                           0.48       440
#    macro avg       0.37      0.27      0.20       440
# weighted avg       0.46      0.48      0.34       440
#
# Accuracy: 0.4863636363636364
#               precision    recall  f1-score   support
#
#       Adults       0.48      1.00      0.65       204
#         Kids       0.00      0.00      0.00        28
#   Older Kids       0.71      0.07      0.12        75
#        Teens       0.62      0.04      0.07       133
#
#     accuracy                           0.49       440
#    macro avg       0.45      0.28      0.21       440
# weighted avg       0.53      0.49      0.34       440
#
# Accuracy: 0.4954545454545455
#               precision    recall  f1-score   support
#
#       Adults       0.50      1.00      0.66       204
#         Kids       1.00      0.04      0.07        28
#   Older Kids       0.67      0.05      0.10        75
#        Teens       0.42      0.08      0.13       133
#
#     accuracy                           0.50       440
#    macro avg       0.64      0.29      0.24       440
# weighted avg       0.53      0.50      0.37       440
# d:\python\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\python\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\python\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 0.475
#               precision    recall  f1-score   support
#
#       Adults       0.48      0.97      0.64       205
#         Kids       0.00      0.00      0.00        29
#   Older Kids       1.00      0.08      0.15        74
#        Teens       0.22      0.03      0.05       132
#
#     accuracy                           0.48       440
#    macro avg       0.43      0.27      0.21       440
# weighted avg       0.46      0.47      0.34       440
#
# Accuracy: 0.475
#               precision    recall  f1-score   support
#
#       Adults       0.48      0.98      0.64       205
#         Kids       0.00      0.00      0.00        29
#   Older Kids       0.80      0.05      0.10        74
#        Teens       0.25      0.03      0.05       132
#
#     accuracy                           0.48       440
#    macro avg       0.38      0.27      0.20       440
# weighted avg       0.43      0.47      0.33       440
# d:\python\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\python\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\python\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\python\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\python\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\python\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 0.48863636363636365
#               precision    recall  f1-score   support
#
#       Adults       0.49      0.98      0.65       205
#         Kids       1.00      0.03      0.07        29
#   Older Kids       0.67      0.08      0.14        74
#        Teens       0.41      0.05      0.09       132
#
#     accuracy                           0.49       440
#    macro avg       0.64      0.29      0.24       440
# weighted avg       0.53      0.49      0.36       440
#
# Accuracy: 0.475
# d:\python\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\python\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\python\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\python\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\python\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\python\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#       Adults       0.48      0.98      0.65       205
#         Kids       0.00      0.00      0.00        29
#   Older Kids       0.43      0.04      0.07        74
#        Teens       0.29      0.04      0.07       132
#
#     accuracy                           0.48       440
#    macro avg       0.30      0.26      0.20       440
# weighted avg       0.39      0.47      0.33       440
#
# Accuracy: 0.4818181818181818
#               precision    recall  f1-score   support
#
#       Adults       0.48      0.99      0.65       205
#         Kids       0.00      0.00      0.00        29
#   Older Kids       1.00      0.09      0.17        74
#        Teens       0.23      0.02      0.04       132
#
#     accuracy                           0.48       440
#    macro avg       0.43      0.28      0.22       440
# weighted avg       0.46      0.48      0.34       440
#
# Accuracy: 0.4772727272727273
#               precision    recall  f1-score   support
#
#       Adults       0.48      0.99      0.65       205
#         Kids       0.00      0.00      0.00        29
#   Older Kids       0.50      0.03      0.05        74
#        Teens       0.38      0.05      0.08       132
#
#     accuracy                           0.48       440
#    macro avg       0.34      0.26      0.19       440
# weighted avg       0.42      0.48      0.33       440
#
# Accuracy: 0.49318181818181817
#               precision    recall  f1-score   support
#
#       Adults       0.49      0.99      0.65       205
#         Kids       1.00      0.03      0.07        29
#   Older Kids       0.56      0.07      0.12        74
#        Teens       0.56      0.07      0.12       132
#
#     accuracy                           0.49       440
#    macro avg       0.65      0.29      0.24       440
# weighted avg       0.56      0.49      0.37       440
# d:\python\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\python\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\python\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 0.49658314350797267
#               precision    recall  f1-score   support
#
#       Adults       0.49      0.99      0.65       205
#         Kids       0.00      0.00      0.00        28
#   Older Kids       0.71      0.07      0.12        74
#        Teens       0.61      0.08      0.15       132
#
#     accuracy                           0.50       439
#    macro avg       0.45      0.28      0.23       439
# weighted avg       0.53      0.50      0.37       439
#
# Accuracy: 0.49658314350797267
#               precision    recall  f1-score   support
#
#       Adults       0.49      0.99      0.65       205
#         Kids       0.00      0.00      0.00        28
#   Older Kids       1.00      0.09      0.17        74
#        Teens       0.53      0.06      0.11       132
#
#     accuracy                           0.50       439
#    macro avg       0.51      0.29      0.23       439
# weighted avg       0.56      0.50      0.37       439
# d:\python\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\python\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\python\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\python\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\python\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\python\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 0.489749430523918
#               precision    recall  f1-score   support
#
#       Adults       0.48      0.99      0.65       205
#         Kids       0.00      0.00      0.00        28
#   Older Kids       0.88      0.09      0.17        74
#        Teens       0.45      0.04      0.07       132
#
#     accuracy                           0.49       439
#    macro avg       0.45      0.28      0.22       439
# weighted avg       0.51      0.49      0.35       439
#
# Accuracy: 0.5034168564920274
#               precision    recall  f1-score   support
#
#       Adults       0.49      1.00      0.66       205
#         Kids       0.00      0.00      0.00        28
#   Older Kids       0.64      0.09      0.16        74
#        Teens       0.82      0.07      0.13       132
#
#     accuracy                           0.50       439
#    macro avg       0.49      0.29      0.24       439
# weighted avg       0.58      0.50      0.37       439
# d:\python\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\python\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\python\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\python\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\python\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\python\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 0.489749430523918
#               precision    recall  f1-score   support
#
#       Adults       0.48      0.98      0.65       205
#         Kids       0.00      0.00      0.00        28
#   Older Kids       0.75      0.08      0.15        74
#        Teens       0.50      0.06      0.11       132
#
#     accuracy                           0.49       439
#    macro avg       0.43      0.28      0.23       439
# weighted avg       0.50      0.49      0.36       439
#
# Accuracy: 0.4874715261958998
#               precision    recall  f1-score   support
#
#       Adults       0.48      0.97      0.65       205
#         Kids       0.00      0.00      0.00        28
#   Older Kids       0.67      0.05      0.10        74
#        Teens       0.50      0.08      0.14       132
#
#     accuracy                           0.49       439
#    macro avg       0.41      0.28      0.22       439
# weighted avg       0.49      0.49      0.36       439
# d:\python\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\python\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\python\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\python\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\python\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\python\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
