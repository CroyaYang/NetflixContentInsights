# %% [markdown]
# ### Modeling using
# ---
# **Goal:**

# %% [markdown]
# use google colab to run

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
os.chdir("/content/gdrive/MyDrive/Colab/github/IMDbXMTC")

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', 500)
import matplotlib.pyplot as plt
# %matplotlib inline
import joblib

# %% [markdown]
# Import train and test dataframes from previous step. They are large files.

# %%
# %%time
train = pd.read_csv('../dataset/Task4preprocessed/netflix_train_dataframe.tsv', sep='\t', index_col=0)
test = pd.read_csv('../dataset/Task4preprocessed/netflix_test_dataframe.tsv', sep='\t', index_col=0)
# Out:
# CPU times: total: 797 ms
# Wall time: 812 ms

# %% [markdown]
# Put the genre and features names (which aren't words) into lists for easy use.

# %%
cols = list(train.columns.values)

# %%
genre_cols = cols[-1]
print(genre_cols)
# Out:
# g_target_ages

# %%
f_names = cols[:2]
print(f_names)
# Out:
# ['title_clean', 'list_clean']

# %% [markdown]
# Separate out X and y out of our train and test .tsv files. We want JUST the genre columns for `y` and everything except the genre columns for `X`.

# %%
y_train = train.loc[:, ~train.columns.isin(['g_target_ages', 'title_clean', 'list_clean'])]
y_test = test[['g_target_ages']]

X_train = train.loc[:, ~train.columns.isin(['g_target_ages', 'title_clean', 'list_clean'])]
X_test = test[['g_target_ages']]

# %% [markdown]
# On going
